# %%
from google.colab import drive # Mount the google drive for data loading
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import some related dependencies
# 1.   Numpy: a package for array transformation
# 2.   Matplotlib: a package for data visualization
# 3.   Tensorflow: a package for neural networks modeling
# 4.   Keras: a package for neural networks modeling which is established on Tensorflow
# 5.   Os: a package for processing files and directories

# %%
import numpy as np #helps for array operation
import matplotlib.pyplot as plt #helps with graphical plots
import tensorflow as tf #helps for ANN model construction
import keras #helps for ANN model construction
import os #helps for create new file folder

# %% [markdown]
# # Test the GPU

# %%
device_name = tf.test.gpu_device_name()  # Current GPU name 
if device_name != '/device:GPU:0':       # Test if the GPU exists
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Load data

# %%
style_url = "https://i.imgur.com/9ooB60I.jpg"                                                                             # Style image
style_image_path = tf.keras.utils.get_file(fname = "/content/drive/MyDrive/Wk_9/skyscraper.JPG", origin = style_url)  # Save style image to an absolute path

base_image_path = '/content/drive/MyDrive/Wk_9/9ooB60I.jpg'      # Absolute path of your customized base image

# %%
# Visualization of raw images
base_image = plt.imread(base_image_path)
style_image = plt.imread(style_image_path)
f, fig = plt.subplots(1,2, figsize=(15,15))
fig[0].imshow(base_image)
fig[1].imshow(style_image)
plt.show()

# %%
def preprocess_image(image_path, img_nrows, img_ncols):
    # Util function to open, resize and format pictures into appropriate tensors
    img = keras.preprocessing.image.load_img(image_path, target_size=(img_nrows, img_ncols))     # Resize the image to img_nrows x img_ncols
    img = keras.preprocessing.image.img_to_array(img)                                            # Convert the image to an array
    img = np.expand_dims(img, axis=0)                                                            # Convert the image array to a sample for next preprocessing step
    img = tf.keras.applications.vgg19.preprocess_input(img)                                      # The image is converted from RGB to BGR and subtracted by [103.939, 116.779, 123.68], which is a mean for BGR channels in Imagenet. Then, each color channel is zero-centered with respect to the ImageNet dataset, without scaling
    return tf.convert_to_tensor(img)                                                             # Convert the image to a tensor
    
def deprocess_image(x):
    '''Helps for image recovery'''
    x = x.reshape((img_nrows, img_ncols, 3))                                                     # Reshape the image
    x[:, :, 0] += 103.939                                                                        # The image is added by [103.939, 116.779, 123.68] for BGR channels, respectively
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    x = x[:, :, ::-1]                                                                            # Convert the BGR image to RGB image
    x = np.clip(x, 0, 255).astype("uint8")                                                       # Convert the float array to int array [0, 255]
    return x

# %%
width, height = keras.preprocessing.image.load_img(base_image_path).size                  # Raw image with a shape of 1920x1200
img_nrows = 400                                                                           # New image height: 400
img_ncols = int(width * img_nrows / height)                                               # New image width: 640

base_image = preprocess_image(base_image_path, img_nrows, img_ncols)                      # New base image tensor after preprocessing
style_image = preprocess_image(style_image_path, img_nrows, img_ncols)                    # New style image tensor after preprocessing
combination_image = tf.Variable(preprocess_image(base_image_path, img_nrows, img_ncols))  # New combination image tensor after preprocessing

# %%
# Visualization of proprecessed images
f, fig = plt.subplots(1, 3, figsize=(15,15))
fig[0].imshow(base_image[0])                 # base_image[0]: convert a sample to an image array 
fig[1].imshow(style_image[0])                
fig[2].imshow(combination_image[0])
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Define loss funtion
# 1. Style loss
# 2. Content loss

# %%
# Calculation of Gram Matrix in style loss
def gram_matrix(x):   
    x = tf.transpose(x, (2, 0, 1))                       # Data is converted to Channel x width x height
    features = tf.reshape(x, (tf.shape(x)[0], -1))       # Data is converted to Channel x (width x height)
    gram = tf.matmul(features, tf.transpose(features))   # Gram Matrix with a shape of Channel x Channel 
    return gram

# %%
# Define style loss
def style_loss(style, combination):
    S = gram_matrix(style)                               # Gram Matrix for the style image: 3x3
    C = gram_matrix(combination)                         # Gram Matrix for the combination image: 3x3
    channels = 3                                         # RGB channels
    size = img_nrows * img_ncols                         
    return tf.reduce_sum(tf.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
# Define content loss
def content_loss(base, combination):
    return tf.reduce_sum(tf.square(combination - base))

# %% [markdown]
# # Load the VGG19 model

# %%
model = tf.keras.applications.vgg19.VGG19(weights="imagenet", include_top=False)   # The model weights are based on the ImageNet
model.summary()

outputs_dict= dict([(layer.name, layer.output) for layer in model.layers])
feature_extractor = keras.Model(inputs=model.inputs, outputs=outputs_dict)         # Feature extracter for all layers in VGG19
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 2s 0us/step
# 80150528/80134624 [==============================] - 2s 0us/step
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv4 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv4 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Calculate the loss using VGG19

# %%
layer_style = ["block1_conv1", "block2_conv1", "block3_conv1", "block4_conv1", "block5_conv1"]  # Layers for style loss calculation 
layer_content = "block5_conv2"                                                                  # Layers for content loss calculation 

content_weight = 2.5e-8                                                                         # Weights for content loss
style_weight = 1e-6                                                                             # Weights for style loss                                                           

def loss_function(combination_image, base_image, style_reference_image):
    input_tensor = tf.concat([base_image, style_reference_image, combination_image], axis=0)    # Combine all the images in a same tensor
    features = feature_extractor(input_tensor)                                                  # Get the values in all the layers for the three images
    loss = tf.zeros(shape=())                                                                   # Initialize the loss                                           

    layer_features = features[layer_content]                                                    # Extract the features for content loss
    base_image_features = layer_features[0, :, :, :]                                            # Features of base image
    combination_features = layer_features[2, :, :, :]                                           # Features of combination image

    loss = loss + content_weight * content_loss(base_image_features, combination_features)      # Content loss

    for layer_name in layer_style:                                                              # Extract the features in each layer to calculate style loss
        layer_features = features[layer_name]                                                   # Features of three images to calculate style loss in each layer 
        style_reference_features = layer_features[1, :, :, :]                                   # Features of style image 
        combination_features = layer_features[2, :, :, :]                                       # Features of combination image 
        sl = style_loss(style_reference_features, combination_features)                         # Style loss between combination image and style image 
        loss += (style_weight / len(layer_style)) * sl                                          # Add style loss 
    return loss

def compute_loss_and_grads(combination_image, base_image, style_reference_image):
    '''Helps for calculate the model loss and gradients of weights'''
    with tf.GradientTape() as tape:
        loss = loss_function(combination_image, base_image, style_reference_image)
    grads = tape.gradient(loss, combination_image)
    return loss, grads

# %%
def create_dir(path):
  folder = os.path.exists(path)
  if not folder:
    os.makedirs(path)
  return path
new_path = create_dir('/content/drive/MyDrive/lab_code/image_generate1/')  # Create a new file folder for saving generated images
print(new_path)
# Out:
# /content/drive/MyDrive/lab_code/image_generate1/

# %%
def result_saver(iteration):
  image_name = new_path +str(iteration) + "_image" + '.png'       # Saved image name
  img = deprocess_image(combination_image.numpy())                                                         # Image recovery
  keras.preprocessing.image.save_img(image_name, img)                                                      # Save image

# %%
optimizer = tf.keras.optimizers.SGD(tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=100.0, decay_steps=100, decay_rate=0.96))
iterations = 4000
for i in range(1, iterations + 1):
    loss, grads = compute_loss_and_grads(combination_image, base_image, style_image)      # Compute model loss and gradients
    optimizer.apply_gradients([(grads, combination_image)])                               # Update model weights
    if i % 10 == 0:                                                                       # Save the combination image per 10 epochs
        print("Iteration %d: loss=%.2f" % (i, loss))
        result_saver(i)
# Out:
# Iteration 10: loss=24119.99
# Iteration 20: loss=14020.92
# Iteration 30: loss=9808.97
# Iteration 40: loss=7466.91
# Iteration 50: loss=5988.81
# Iteration 60: loss=4983.90
# Iteration 70: loss=4260.69
# Iteration 80: loss=3716.35
# Iteration 90: loss=3294.62
# Iteration 100: loss=2958.82
# Iteration 110: loss=2685.41
# Iteration 120: loss=2458.70
# Iteration 130: loss=2268.13
# Iteration 140: loss=2104.88
# Iteration 150: loss=1963.39
# Iteration 160: loss=1839.70
# Iteration 170: loss=1730.40
# Iteration 180: loss=1633.47
# Iteration 190: loss=1546.89
# Iteration 200: loss=1468.97
# Iteration 210: loss=1398.64
# Iteration 220: loss=1335.07
# Iteration 230: loss=1277.31
# Iteration 240: loss=1224.49
# Iteration 250: loss=1175.89
# Iteration 260: loss=1131.02
# Iteration 270: loss=1089.55
# Iteration 280: loss=1051.46
# Iteration 290: loss=1016.22
# Iteration 300: loss=983.41
# Iteration 310: loss=952.91
# Iteration 320: loss=924.46
# Iteration 330: loss=898.01
# Iteration 340: loss=873.23
# Iteration 350: loss=849.95
# Iteration 360: loss=828.04
# Iteration 370: loss=807.50
# Iteration 380: loss=788.07
# Iteration 390: loss=769.78
# Iteration 400: loss=752.50
# Iteration 410: loss=736.11
# Iteration 420: loss=720.60
# Iteration 430: loss=705.96
# Iteration 440: loss=692.04
# Iteration 450: loss=678.79
# Iteration 460: loss=666.21
# Iteration 470: loss=654.26
# Iteration 480: loss=642.84
# Iteration 490: loss=631.90
# Iteration 500: loss=621.43
# Iteration 510: loss=611.42
# Iteration 520: loss=601.83
# Iteration 530: loss=592.62
# Iteration 540: loss=583.78
# Iteration 550: loss=575.30
# Iteration 560: loss=567.14
# Iteration 570: loss=559.30
# Iteration 580: loss=551.72
# Iteration 590: loss=544.43
# Iteration 600: loss=537.40
# Iteration 610: loss=530.62
# Iteration 620: loss=524.08
# Iteration 630: loss=517.78
# Iteration 640: loss=511.67
# Iteration 650: loss=505.75
# Iteration 660: loss=500.01
# Iteration 670: loss=494.46
# Iteration 680: loss=489.09
# Iteration 690: loss=483.90
# Iteration 700: loss=478.88
# Iteration 710: loss=474.01
# Iteration 720: loss=469.28
# Iteration 730: loss=464.69
# Iteration 740: loss=460.23
# Iteration 750: loss=455.89
# Iteration 760: loss=451.68
# Iteration 770: loss=447.58
# Iteration 780: loss=443.58
# Iteration 790: loss=439.69
# Iteration 800: loss=435.90
# Iteration 810: loss=432.20
# Iteration 820: loss=428.60
# Iteration 830: loss=425.08
# Iteration 840: loss=421.65
# Iteration 850: loss=418.30
# Iteration 860: loss=415.04
# Iteration 870: loss=411.86
# Iteration 880: loss=408.76
# Iteration 890: loss=405.73
# Iteration 900: loss=402.76
# Iteration 910: loss=399.87
# Iteration 920: loss=397.03
# Iteration 930: loss=394.26
# Iteration 940: loss=391.55
# Iteration 950: loss=388.92
# Iteration 960: loss=386.33
# Iteration 970: loss=383.80
# Iteration 980: loss=381.33
# Iteration 990: loss=378.91
# Iteration 1000: loss=376.53
# Iteration 1010: loss=374.20
# Iteration 1020: loss=371.92
# Iteration 1030: loss=369.68
# Iteration 1040: loss=367.49
# Iteration 1050: loss=365.34
# Iteration 1060: loss=363.24
# Iteration 1070: loss=361.18
# Iteration 1080: loss=359.15
# Iteration 1090: loss=357.16
# Iteration 1100: loss=355.20
# Iteration 1110: loss=353.28
# Iteration 1120: loss=351.40
# Iteration 1130: loss=349.56
# Iteration 1140: loss=347.76
# Iteration 1150: loss=345.99
# Iteration 1160: loss=344.26
# Iteration 1170: loss=342.55
# Iteration 1180: loss=340.87
# Iteration 1190: loss=339.22
# Iteration 1200: loss=337.60
# Iteration 1210: loss=336.01
# Iteration 1220: loss=334.45
# Iteration 1230: loss=332.91
# Iteration 1240: loss=331.40
# Iteration 1250: loss=329.90
# Iteration 1260: loss=328.44
# Iteration 1270: loss=326.99
# Iteration 1280: loss=325.57
# Iteration 1290: loss=324.18
# Iteration 1300: loss=322.80
# Iteration 1310: loss=321.45
# Iteration 1320: loss=320.11
# Iteration 1330: loss=318.80
# Iteration 1340: loss=317.51
# Iteration 1350: loss=316.24
# Iteration 1360: loss=315.00
# Iteration 1370: loss=313.77
# Iteration 1380: loss=312.56
# Iteration 1390: loss=311.37
# Iteration 1400: loss=310.21
# Iteration 1410: loss=309.06
# Iteration 1420: loss=307.93
# Iteration 1430: loss=306.81
# Iteration 1440: loss=305.72
# Iteration 1450: loss=304.64
# Iteration 1460: loss=303.57
# Iteration 1470: loss=302.52
# Iteration 1480: loss=301.48
# Iteration 1490: loss=300.46
# Iteration 1500: loss=299.45
# Iteration 1510: loss=298.46
# Iteration 1520: loss=297.48
# Iteration 1530: loss=296.52
# Iteration 1540: loss=295.57
# Iteration 1550: loss=294.63
# Iteration 1560: loss=293.70
# Iteration 1570: loss=292.79
# Iteration 1580: loss=291.88
# Iteration 1590: loss=290.99
# Iteration 1600: loss=290.12
# Iteration 1610: loss=289.25
# Iteration 1620: loss=288.39
# Iteration 1630: loss=287.55
# Iteration 1640: loss=286.72
# Iteration 1650: loss=285.89
# Iteration 1660: loss=285.08
# Iteration 1670: loss=284.28
# Iteration 1680: loss=283.48
# Iteration 1690: loss=282.70
# Iteration 1700: loss=281.92
# Iteration 1710: loss=281.16
# Iteration 1720: loss=280.40
# Iteration 1730: loss=279.66
# Iteration 1740: loss=278.92
# Iteration 1750: loss=278.18
# Iteration 1760: loss=277.46
# Iteration 1770: loss=276.75
# Iteration 1780: loss=276.04
# Iteration 1790: loss=275.34
# Iteration 1800: loss=274.65
# Iteration 1810: loss=273.97
# Iteration 1820: loss=273.30
# Iteration 1830: loss=272.63
# Iteration 1840: loss=271.97
# Iteration 1850: loss=271.32
# Iteration 1860: loss=270.67
# Iteration 1870: loss=270.04
# Iteration 1880: loss=269.41
# Iteration 1890: loss=268.78
# Iteration 1900: loss=268.17
# Iteration 1910: loss=267.56
# Iteration 1920: loss=266.95
# Iteration 1930: loss=266.36
# Iteration 1940: loss=265.77
# Iteration 1950: loss=265.18
# Iteration 1960: loss=264.61
# Iteration 1970: loss=264.03
# Iteration 1980: loss=263.47
# Iteration 1990: loss=262.91
# Iteration 2000: loss=262.36
# Iteration 2010: loss=261.81
# Iteration 2020: loss=261.27
# Iteration 2030: loss=260.73
# Iteration 2040: loss=260.20
# Iteration 2050: loss=259.67
# Iteration 2060: loss=259.15
# Iteration 2070: loss=258.64
# Iteration 2080: loss=258.13
# Iteration 2090: loss=257.62
# Iteration 2100: loss=257.12
# Iteration 2110: loss=256.63
# Iteration 2120: loss=256.14
# Iteration 2130: loss=255.65
# Iteration 2140: loss=255.17
# Iteration 2150: loss=254.70
# Iteration 2160: loss=254.23
# Iteration 2170: loss=253.76
# Iteration 2180: loss=253.30
# Iteration 2190: loss=252.85
# Iteration 2200: loss=252.40
# Iteration 2210: loss=251.95
# Iteration 2220: loss=251.50
# Iteration 2230: loss=251.07
# Iteration 2240: loss=250.63
# Iteration 2250: loss=250.20
# Iteration 2260: loss=249.78
# Iteration 2270: loss=249.35
# Iteration 2280: loss=248.94
# Iteration 2290: loss=248.52
# Iteration 2300: loss=248.11
# Iteration 2310: loss=247.70
# Iteration 2320: loss=247.29
# Iteration 2330: loss=246.89
# Iteration 2340: loss=246.50
# Iteration 2350: loss=246.10
# Iteration 2360: loss=245.71
# Iteration 2370: loss=245.32
# Iteration 2380: loss=244.94
# Iteration 2390: loss=244.56
# Iteration 2400: loss=244.18
# Iteration 2410: loss=243.81
# Iteration 2420: loss=243.44
# Iteration 2430: loss=243.07
# Iteration 2440: loss=242.70
# Iteration 2450: loss=242.34
# Iteration 2460: loss=241.98
# Iteration 2470: loss=241.63
# Iteration 2480: loss=241.27
# Iteration 2490: loss=240.92
# Iteration 2500: loss=240.58
# Iteration 2510: loss=240.24
# Iteration 2520: loss=239.90
# Iteration 2530: loss=239.56
# Iteration 2540: loss=239.23
# Iteration 2550: loss=238.90
# Iteration 2560: loss=238.57
# Iteration 2570: loss=238.24
# Iteration 2580: loss=237.92
# Iteration 2590: loss=237.60
# Iteration 2600: loss=237.28
# Iteration 2610: loss=236.97
# Iteration 2620: loss=236.66
# Iteration 2630: loss=236.35
# Iteration 2640: loss=236.05
# Iteration 2650: loss=235.74
# Iteration 2660: loss=235.44
# Iteration 2670: loss=235.14
# Iteration 2680: loss=234.84
# Iteration 2690: loss=234.55
# Iteration 2700: loss=234.26
# Iteration 2710: loss=233.97
# Iteration 2720: loss=233.68
# Iteration 2730: loss=233.40
# Iteration 2740: loss=233.11
# Iteration 2750: loss=232.83
# Iteration 2760: loss=232.55
# Iteration 2770: loss=232.28
# Iteration 2780: loss=232.00
# Iteration 2790: loss=231.73
# Iteration 2800: loss=231.46
# Iteration 2810: loss=231.19
# Iteration 2820: loss=230.93
# Iteration 2830: loss=230.66
# Iteration 2840: loss=230.40
# Iteration 2850: loss=230.14
# Iteration 2860: loss=229.88
# Iteration 2870: loss=229.62
# Iteration 2880: loss=229.37
# Iteration 2890: loss=229.11
# Iteration 2900: loss=228.86
# Iteration 2910: loss=228.61
# Iteration 2920: loss=228.37
# Iteration 2930: loss=228.12
# Iteration 2940: loss=227.88
# Iteration 2950: loss=227.64
# Iteration 2960: loss=227.40
# Iteration 2970: loss=227.16
# Iteration 2980: loss=226.92
# Iteration 2990: loss=226.69
# Iteration 3000: loss=226.46
# Iteration 3010: loss=226.23
# Iteration 3020: loss=226.00
# Iteration 3030: loss=225.77
# Iteration 3040: loss=225.54
# Iteration 3050: loss=225.32
# Iteration 3060: loss=225.10
# Iteration 3070: loss=224.87
# Iteration 3080: loss=224.65
# Iteration 3090: loss=224.44
# Iteration 3100: loss=224.22
# Iteration 3110: loss=224.01
# Iteration 3120: loss=223.79
# Iteration 3130: loss=223.58
# Iteration 3140: loss=223.37
# Iteration 3150: loss=223.16
# Iteration 3160: loss=222.95
# Iteration 3170: loss=222.74
# Iteration 3180: loss=222.54
# Iteration 3190: loss=222.33
# Iteration 3200: loss=222.13
# Iteration 3210: loss=221.93
# Iteration 3220: loss=221.73
# Iteration 3230: loss=221.53
# Iteration 3240: loss=221.33
# Iteration 3250: loss=221.13
# Iteration 3260: loss=220.94
# Iteration 3270: loss=220.75
# Iteration 3280: loss=220.55
# Iteration 3290: loss=220.36
# Iteration 3300: loss=220.17
# Iteration 3310: loss=219.98
# Iteration 3320: loss=219.80
# Iteration 3330: loss=219.61
# Iteration 3340: loss=219.42
# Iteration 3350: loss=219.24
# Iteration 3360: loss=219.06
# Iteration 3370: loss=218.88
# Iteration 3380: loss=218.70
# Iteration 3390: loss=218.52
# Iteration 3400: loss=218.34
# Iteration 3410: loss=218.16
# Iteration 3420: loss=217.99
# Iteration 3430: loss=217.81
# Iteration 3440: loss=217.64
# Iteration 3450: loss=217.46
# Iteration 3460: loss=217.29
# Iteration 3470: loss=217.12
# Iteration 3480: loss=216.95
# Iteration 3490: loss=216.79
# Iteration 3500: loss=216.62
# Iteration 3510: loss=216.45
# Iteration 3520: loss=216.29
# Iteration 3530: loss=216.12
# Iteration 3540: loss=215.96
# Iteration 3550: loss=215.80
# Iteration 3560: loss=215.64
# Iteration 3570: loss=215.48
# Iteration 3580: loss=215.32
# Iteration 3590: loss=215.16
# Iteration 3600: loss=215.01
# Iteration 3610: loss=214.85
# Iteration 3620: loss=214.70
# Iteration 3630: loss=214.55
# Iteration 3640: loss=214.39
# Iteration 3650: loss=214.24
# Iteration 3660: loss=214.09
# Iteration 3670: loss=213.94
# Iteration 3680: loss=213.79
# Iteration 3690: loss=213.65
# Iteration 3700: loss=213.50
# Iteration 3710: loss=213.35
# Iteration 3720: loss=213.21
# Iteration 3730: loss=213.06
# Iteration 3740: loss=212.92
# Iteration 3750: loss=212.78
# Iteration 3760: loss=212.63
# Iteration 3770: loss=212.49
# Iteration 3780: loss=212.35
# Iteration 3790: loss=212.21
# Iteration 3800: loss=212.07
# Iteration 3810: loss=211.94
# Iteration 3820: loss=211.80
# Iteration 3830: loss=211.66
# Iteration 3840: loss=211.53
# Iteration 3850: loss=211.39
# Iteration 3860: loss=211.26
# Iteration 3870: loss=211.13
# Iteration 3880: loss=210.99
# Iteration 3890: loss=210.86
# Iteration 3900: loss=210.73
# Iteration 3910: loss=210.60
# Iteration 3920: loss=210.47
# Iteration 3930: loss=210.34
# Iteration 3940: loss=210.21
# Iteration 3950: loss=210.09
# Iteration 3960: loss=209.96
# Iteration 3970: loss=209.84
# Iteration 3980: loss=209.71
# Iteration 3990: loss=209.59
# Iteration 4000: loss=209.46

# %%
# Visualization of generated images
generated_image_100 = plt.imread("/content/drive/MyDrive/lab_code/image_generate1/100_image.png")   # Generated image on the 100th epoch
generated_image_1000 = plt.imread("/content/drive/MyDrive/lab_code/image_generate1/1000_image.png") # Generated image on the 1000th epoch
generated_image_2000 = plt.imread("/content/drive/MyDrive/lab_code/image_generate1/2000_image.png") # Generated image on the 2000th epoch
generated_image_3000 = plt.imread("/content/drive/MyDrive/lab_code/image_generate1/3000_image.png") # Generated image on the 3000th epoch
generated_image_4000 = plt.imread("/content/drive/MyDrive/lab_code/image_generate1/4000_image.png") # Generated image on the 4000th epoch
f, fig = plt.subplots(1,5, figsize=(20,20))
fig[0].imshow(generated_image_100)
fig[1].imshow(generated_image_1000)
fig[2].imshow(generated_image_2000)
fig[3].imshow(generated_image_3000)
fig[4].imshow(generated_image_4000)
plt.show()
